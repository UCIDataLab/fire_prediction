# %%
import cPickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from time import time
os.chdir(u'/Users/zbutler/research/fire_prediction')
from data import data
from geometry.grid_conversion import ak_bb, fairbanks_lat_lon, get_latlon_xy_fxns
from prediction.fire_clustering import cluster_over_time_with_merging, FIRE_SEASON
# %matplotlib inline

# %%
# Load all data
modis = data.load_modis() 
gfs_dict = data.load_gfs_dict()
min_year = np.min(modis.year)
max_year = np.max(modis.year)

# %%
# Add daymonth to standard modis dataset and save it
from carpentry.get_feat_df import add_daymonth
modis = add_daymonth(modis)
with open("data/ak_fires.pkl", "w") as fout:
    cPickle.dump(modis, fout, protocol=cPickle.HIGHEST_PROTOCOL)
modis = data.load_modis()
modis.iloc[0:10]
# Out:
#          confidence  day   frp  hour     lat     long  minute  month  year  \
# 1448868        0.24    1   7.1    22  64.808 -147.609      19      5  2007
# 1600851        0.53   17  13.3    22  60.046 -151.492      33      5  2007
# 1610427        0.43   19  23.8    23  67.019 -158.293      44      5  2007
# 1623204        0.35   21   4.5    20  62.808 -138.762      16      5  2007
# 1628928        0.81   21  16.8    22  63.922 -146.422       9      5  2007
# 1628929        0.59   21   8.2    22  63.919 -146.442       9      5  2007
# 1631442        0.74   22  26.9    20  66.646 -149.651      58      5  2007
# 1636860        0.80   23  19.2     6  66.637 -149.673      40      5  2007
# 1636861        0.63   23  13.1     6  66.651 -149.660      40      5  2007
# 1636862        0.97   23  27.1     6  66.646 -149.684      40      5  2007
#
#                    x         y  dayofyear
# 1448868  1046.361463  1088.688        121
# 1600851   862.434548   560.106        137
# 1610427   566.748464  1334.109        139
# 1623204  1509.981794   866.688        141
# 1628928  1110.487294   990.342        141
# 1628929  1109.535052   990.009        141
# 1631442   943.584150  1292.706        142
# 1636860   942.642644  1291.707        143
# 1636861   943.170580  1293.261        143
# 1636862   942.127898  1292.706        143

# %%
# Try a bunch of potential clustering thresholds, see what seems like it makes sense
threshes = [2.5, 5, 10, 20, 50, 100]
n_clust_arr = []
n_merge_arr = []
for thresh in threshes:
    t = time()
    clust_annual = []
    merge_annual = []
    for year in xrange(min_year, max_year+1):
        clust_df, merge_dict = cluster_over_time_with_merging(modis[modis.year==year], thresh)
        clust_annual.append(len(clust_df.cluster.unique()))
        merge_annual.append(len(merge_dict))
    print "%f thresh took %f sec" %(thresh, time() - t)
    n_clust_arr.append(clust_annual)
    n_merge_arr.append(merge_annual)
# Out:
# len of pairs list: 83413
# done building dict
# 6 merges in year 2007
# prediction/fire_clustering.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['cluster'] = pd.Series(clust_dict, dtype=int)
# len of pairs list: 20856
# done building dict
# 2 merges in year 2008
# len of pairs list: 786897
# done building dict
# 55 merges in year 2009
# len of pairs list: 127242
# done building dict
# 26 merges in year 2010
# len of pairs list: 16562
# done building dict
# 10 merges in year 2011
# len of pairs list: 13587
# done building dict
# 7 merges in year 2012
# len of pairs list: 192751
# done building dict
# 26 merges in year 2013
# len of pairs list: 16282
# done building dict
# 1 merges in year 2014
# len of pairs list: 629305
# done building dict
# 135 merges in year 2015
# len of pairs list: 60777
# done building dict
# 7 merges in year 2016
# 2.500000 thresh took 40.908651 sec
# len of pairs list: 198715
# done building dict
# 0 merges in year 2007
# len of pairs list: 55574
# done building dict
# 0 merges in year 2008
# len of pairs list: 2447912
# done building dict
# 13 merges in year 2009
# len of pairs list: 324658
# done building dict
# 5 merges in year 2010
# len of pairs list: 41704
# done building dict
# 4 merges in year 2011
# len of pairs list: 31607
# done building dict
# 2 merges in year 2012
# len of pairs list: 458753
# done building dict
# 10 merges in year 2013
# len of pairs list: 46785
# done building dict
# 0 merges in year 2014
# len of pairs list: 1789586
# done building dict
# 57 merges in year 2015
# len of pairs list: 150766
# done building dict
# 4 merges in year 2016
# 5.000000 thresh took 78.474148 sec
# len of pairs list: 413592
# done building dict
# 1 merges in year 2007
# len of pairs list: 118713
# done building dict
# 1 merges in year 2008
# len of pairs list: 6898623
# done building dict
# 13 merges in year 2009
# len of pairs list: 697929
# done building dict
# 4 merges in year 2010
# len of pairs list: 80250
# done building dict
# 3 merges in year 2011
# len of pairs list: 53431
# done building dict
# 1 merges in year 2012
# len of pairs list: 947849
# done building dict
# 6 merges in year 2013
# len of pairs list: 128064
# done building dict
# 0 merges in year 2014
# len of pairs list: 4475813
# done building dict
# 52 merges in year 2015
# len of pairs list: 298395
# done building dict
# 6 merges in year 2016
# 10.000000 thresh took 151.151835 sec
# len of pairs list: 695189
# done building dict
# 3 merges in year 2007
# len of pairs list: 143584
# done building dict
# 1 merges in year 2008
# len of pairs list: 17160637
# done building dict
# 11 merges in year 2009
# len of pairs list: 1052846
# done building dict
# 6 merges in year 2010
# len of pairs list: 107227
# done building dict
# 3 merges in year 2011
# len of pairs list: 68279
# done building dict
# 2 merges in year 2012
# len of pairs list: 1480722
# done building dict
# 10 merges in year 2013
# len of pairs list: 321109
# done building dict
# 0 merges in year 2014
# len of pairs list: 9363027
# done building dict
# 41 merges in year 2015
# len of pairs list: 460004
# done building dict
# 3 merges in year 2016
# 20.000000 thresh took 283.678053 sec
# len of pairs list: 1057298
# done building dict
# 16 merges in year 2007
# len of pairs list: 153730
# done building dict
# 2 merges in year 2008
# len of pairs list: 38998831
# done building dict
# 24 merges in year 2009
# len of pairs list: 1749894
# done building dict
# 16 merges in year 2010
# len of pairs list: 119289
# done building dict
# 3 merges in year 2011
# len of pairs list: 97505
# done building dict
# 4 merges in year 2012
# len of pairs list: 2090005
# done building dict
# 16 merges in year 2013
# len of pairs list: 451212
# done building dict
# 0 merges in year 2014
# len of pairs list: 24631121
# done building dict
# 31 merges in year 2015
# len of pairs list: 725750
# done building dict
# 5 merges in year 2016
# 50.000000 thresh took 656.000663 sec
# len of pairs list: 1274269
# done building dict
# 18 merges in year 2007
# len of pairs list: 167865
# done building dict
# 2 merges in year 2008
# len of pairs list: 69239716
# done building dict
# 15 merges in year 2009
# len of pairs list: 3108180
# done building dict
# 17 merges in year 2010
# len of pairs list: 165250
# done building dict
# 9 merges in year 2011
# len of pairs list: 135589
# done building dict
# 10 merges in year 2012
# len of pairs list: 3306941
# done building dict
# 24 merges in year 2013
# len of pairs list: 457283
# done building dict
# 0 merges in year 2014
# len of pairs list: 72675312
# done building dict
# 28 merges in year 2015
# len of pairs list: 1331525
# done building dict
# 12 merges in year 2016
# 100.000000 thresh took 2383.344872 sec

# %%
marker_arr = ['b--', 'k--', 'r--', 'g--', 'y--', 'b-', 'r-']
plt.figure(figsize=(10,7))
for i, thresh in enumerate(threshes):
    plt.plot(np.arange(min_year, max_year+1), n_clust_arr[i], marker_arr[i], label="Thresh %.2f" % thresh)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_useOffset(False)
plt.xlabel("Year")
plt.ylabel("Number of clusters")
plt.savefig("pics/n_clusts_by_year.png")
plt.show()
plt.close()
plt.figure(figsize=(10,7))
for i, thresh in enumerate(threshes):
    plt.plot(np.arange(min_year, max_year+1), n_merge_arr[i], marker_arr[i], label="Thresh %.2f" % thresh)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_useOffset(False)
plt.xlabel("Year")
plt.ylabel("Number of merged fires this fire season")
plt.savefig("pics/n_merges_by_year.png")
plt.show()
plt.close()

# %%
# Get the cluster data set we want
import prediction.fire_clustering as fc
reload(fc)
from prediction.fire_clustering import cluster_over_time_with_merging, FIRE_SEASON

tau_f = 10.
merge_dict_dict = dict()
clust_df, merge_dict_dict = cluster_over_time_with_merging(modis, tau_f)
print "Big clust df size: " + str(clust_df)
with open("data/merge_dict_dict.pkl", "w") as fpkl:
    cPickle.dump(merge_dict_dict, fpkl, protocol=cPickle.HIGHEST_PROTOCOL)
with open("data/clust_df.pkl", "w") as fpkl:
    cPickle.dump(clust_df, fpkl, protocol=cPickle.HIGHEST_PROTOCOL)
clust_df.iloc[0:10]
# Out:
# len of pairs list: 413592
# done building dict
# 1 merges in year 2007
# len of pairs list: 118713
# done building dict
# 1 merges in year 2008
# len of pairs list: 6898623
# done building dict
# 13 merges in year 2009
# len of pairs list: 697929
# done building dict
# 4 merges in year 2010
# len of pairs list: 80250
# done building dict
# 3 merges in year 2011
# len of pairs list: 53431
# done building dict
# 1 merges in year 2012
# len of pairs list: 947849
# done building dict
# 6 merges in year 2013
# len of pairs list: 128064
# done building dict
# 0 merges in year 2014
# len of pairs list: 4475813
# done building dict
# 52 merges in year 2015
# len of pairs list: 298395
# done building dict
# 6 merges in year 2016
# Big clust df size:           confidence  day    frp  hour     lat     long  minute  month  year  \
# 1448868         0.24    1    7.1    22  64.808 -147.609      19      5  2007
# 1600851         0.53   17   13.3    22  60.046 -151.492      33      5  2007
# 1610427         0.43   19   23.8    23  67.019 -158.293      44      5  2007
# 1623204         0.35   21    4.5    20  62.808 -138.762      16      5  2007
# 1628928         0.81   21   16.8    22  63.922 -146.422       9      5  2007
# 1628929         0.59   21    8.2    22  63.919 -146.442       9      5  2007
# 1631442         0.74   22   26.9    20  66.646 -149.651      58      5  2007
# 1636860         0.80   23   19.2     6  66.637 -149.673      40      5  2007
# 1636861         0.63   23   13.1     6  66.651 -149.660      40      5  2007
# 1636862         0.97   23   27.1     6  66.646 -149.684      40      5  2007
# 1636863         0.46   23   11.6     6  66.641 -149.708      40      5  2007
# 1637068         0.36   23   30.6     8  66.651 -149.657      18      5  2007
# 1639308         0.72   23    8.6    21  63.906 -146.470      42      5  2007
# 1639309         0.41   23   10.3    21  63.898 -146.428      42      5  2007
# 1639310         0.78   23   13.7    21  63.894 -146.407      42      5  2007
# 1639311         0.76   23   12.7    21  63.890 -146.387      42      5  2007
# 1642998         0.88   23   25.6    12  66.651 -149.627      17      5  2007
# 1644393         0.30   23   41.4    20  66.628 -149.695      21      5  2007
# 1644411         0.70   23   13.9    21  63.892 -146.382      57      5  2007
# 1644412         0.83   23   22.0    21  63.888 -146.403      57      5  2007
# 1644413         0.32   23    7.0    21  63.898 -146.460      57      5  2007
# 1645489         1.00   24  307.3     9  64.795 -151.235       1      5  2007
# 1645490         1.00   24  227.4     9  64.794 -151.238       1      5  2007
# 1646800         0.48   24   61.9    20  66.671 -149.637      46      5  2007
# 1646801         0.63   24   81.9    20  66.661 -149.688      46      5  2007
# 1646802         0.79   24  125.7    20  66.659 -149.645      46      5  2007
# 1646803         0.59   24   60.7    20  66.669 -149.645      46      5  2007
# 1646804         0.63   24   73.6    20  66.660 -149.695      46      5  2007
# 1646805         0.63   24   83.8    20  66.657 -149.652      46      5  2007
# 1646806         0.91   24  105.0    20  66.635 -149.703      46      5  2007
# ...              ...  ...    ...   ...     ...      ...     ...    ...   ...
# 44793039        0.00   27    3.9    21  67.475 -145.202      51      7  2016
# 44793040        0.23   27   26.8    21  66.186 -155.573      51      7  2016
# 44793149        0.78   27   52.3    23  66.188 -155.579      29      7  2016
# 44793150        0.30   27   30.9    23  66.185 -155.616      29      7  2016
# 44793151        0.65   27   73.1    23  66.199 -155.584      29      7  2016
# 44793152        0.81   27   96.4    23  66.210 -155.589      29      7  2016
# 44793153        0.38   27   42.0    23  66.197 -155.591      29      7  2016
# 44793154        0.92   27  144.8    23  66.209 -155.596      29      7  2016
# 44849366        0.26   30    5.0    22  61.252 -145.178      20      7  2016
# 44896700        0.75    2   14.4    21  63.715 -144.930       0      8  2016
# 44940029        0.44    4    9.6    22  67.089 -153.004      25      8  2016
# 44959002        0.12    5   43.8     0  66.792 -153.516       3      8  2016
# 45149429        0.50   14    3.6    23  62.310 -158.885      16      8  2016
# 45452451        0.18    1    3.4    23  59.547 -160.323       3      9  2016
# 45456215        0.44    2    5.7    21  61.029 -161.191      56      9  2016
# 45456224        0.44    2   32.0    23  61.031 -161.183      34      9  2016
# 45464537        0.30    2    5.7    22  60.896 -141.612       8      9  2016
# 45464708        0.66    2   17.6    23  61.031 -161.195      46      9  2016
# 45468431        0.31    3    8.4    21  61.788 -142.540       0      9  2016
# 45468432        0.35    3   10.5    21  61.234 -146.863       1      9  2016
# 45476694        0.12    3    7.5    22  62.265 -143.176      51      9  2016
# 45480784        0.49    4    5.3    21  64.706 -146.299      42      9  2016
# 45480785        0.86    4   31.6    21  64.702 -146.277      42      9  2016
# 45487213        0.68    4   12.3    21  64.696 -146.295      57      9  2016
# 45558193        0.58    9   13.6    23  70.216 -159.680      38      9  2016
# 45914801        0.61    2   21.2    22  63.964 -145.299       7     10  2016
# 45918861        0.80    2   22.5    22  63.968 -145.298      21     10  2016
# 45918862        0.78    2   20.5    22  63.965 -145.319      21     10  2016
# 45918863        0.28    2    9.6    22  63.974 -145.325      21     10  2016
# 46005892        0.00   12    9.3    22  66.870 -160.883      43     10  2016
#
#                     x         y  dayofyear  cluster
# 1448868   1046.361463  1088.688        121      NaN
# 1600851    862.434548   560.106        137      0.0
# 1610427    566.748464  1334.109        139      1.0
# 1623204   1509.981794   866.688        141      2.0
# 1628928   1110.487294   990.342        141      3.0
# 1628929   1109.535052   990.009        141      3.0
# 1631442    943.584150  1292.706        142      4.0
# 1636860    942.642644  1291.707        143      4.0
# 1636861    943.170580  1293.261        143      4.0
# 1636862    942.127898  1292.706        143      4.0
# 1636863    941.084787  1292.151        143      4.0
# 1637068    943.302939  1293.261        143      4.0
# 1639308   1108.278800   988.566        143      3.0
# 1639309   1110.406086   987.678        143      3.0
# 1639310   1111.470167   987.234        143      3.0
# 1639311   1112.485547   986.790        143      3.0
# 1642998    944.626538  1293.261        143      4.0
# 1644393    941.700430  1290.708        143      4.0
# 1644411   1112.712649   987.012        143      3.0
# 1644412   1111.719462   986.568        143      3.0
# 1644413   1108.838791   987.678        143      3.0
# 1645489    874.552729  1087.245        144      5.0
# 1645490    874.410969  1087.134        144      5.0
# 1646800    944.118869  1295.481        144      4.0
# 1646801    941.902897  1294.371        144      4.0
# 1646802    943.805906  1294.149        144      4.0
# 1646803    943.772813  1295.259        144      4.0
# 1646804    941.597403  1294.260        144      4.0
# 1646805    943.503760  1293.927        144      4.0
# 1646806    941.324707  1291.485        144      4.0
# ...               ...       ...        ...      ...
# 44793039  1130.571708  1384.725        207     48.0
# 44793040   678.916874  1241.646        207     25.0
# 44793149   678.661687  1241.868        207     25.0
# 44793150   676.976796  1241.535        207     25.0
# 44793151   678.516822  1243.089        207     25.0
# 44793152   678.372159  1244.310        207     25.0
# 44793153   678.187803  1242.867        207     25.0
# 44793154   678.050540  1244.199        207     25.0
# 44849366  1200.474466   693.972        210    107.0
# 44896700  1185.871169   967.365        213    111.0
# 44940029   796.810503  1341.879        215     35.0
# 44959002   773.551404  1308.912        216     53.0
# 45149429   479.967688   811.410        225     62.0
# 45452451   364.187598   504.717        243      NaN
# 45456215   339.449180   669.219        244      NaN
# 45456224   339.913460   669.441        244      NaN
# 45464537  1397.386831   654.456        244      NaN
# 45464708   339.266458   669.441        244      NaN
# 45468431  1333.513200   753.468        245      NaN
# 45468432  1110.400480   691.974        245      NaN
# 45476694  1293.230356   806.415        245      NaN
# 45480784  1109.366945  1077.366        246      NaN
# 45480785  1110.450039  1076.922        246      NaN
# 45487213  1109.648628  1076.256        246      NaN
# 45558193   553.772443  1688.976        251      NaN
# 45914801  1164.987926   995.004        274      NaN
# 45918861  1164.993480   995.448        274      NaN
# 45918862  1163.999880   995.115        274      NaN
# 45918863  1163.609690   996.114        274      NaN
# 46005892   451.680974  1317.570        284      NaN
#
# [96218 rows x 13 columns]
#          confidence  day   frp  hour     lat     long  minute  month  year  \
# 1448868        0.24    1   7.1    22  64.808 -147.609      19      5  2007
# 1600851        0.53   17  13.3    22  60.046 -151.492      33      5  2007
# 1610427        0.43   19  23.8    23  67.019 -158.293      44      5  2007
# 1623204        0.35   21   4.5    20  62.808 -138.762      16      5  2007
# 1628928        0.81   21  16.8    22  63.922 -146.422       9      5  2007
# 1628929        0.59   21   8.2    22  63.919 -146.442       9      5  2007
# 1631442        0.74   22  26.9    20  66.646 -149.651      58      5  2007
# 1636860        0.80   23  19.2     6  66.637 -149.673      40      5  2007
# 1636861        0.63   23  13.1     6  66.651 -149.660      40      5  2007
# 1636862        0.97   23  27.1     6  66.646 -149.684      40      5  2007
#
#                    x         y  dayofyear  cluster
# 1448868  1046.361463  1088.688        121      NaN
# 1600851   862.434548   560.106        137      0.0
# 1610427   566.748464  1334.109        139      1.0
# 1623204  1509.981794   866.688        141      2.0
# 1628928  1110.487294   990.342        141      3.0
# 1628929  1109.535052   990.009        141      3.0
# 1631442   943.584150  1292.706        142      4.0
# 1636860   942.642644  1291.707        143      4.0
# 1636861   943.170580  1293.261        143      4.0
# 1636862   942.127898  1292.706        143      4.0

# %%
# Now, make some plots comparing the number of fires in new clusters vs fires in preexisting fires
years = range(min_year, max_year+1)
days = range(FIRE_SEASON[0], FIRE_SEASON[1]+1)
new_fires_mat = np.zeros((len(years), len(days)))
preex_fires_mat = np.zeros((len(years), len(days)))

for i,year in enumerate(years):
    annual_fires = clust_df[clust_df.year == year]
    clust2startday = dict()
    for clust in annual_fires.cluster.unique():
        clust2startday[clust] = np.min(annual_fires[annual_fires.cluster==clust].dayofyear)
    for j,day in enumerate(days):
        daily_fires = annual_fires[annual_fires.dayofyear == day]
        counts = daily_fires.cluster.value_counts()
        for clust, count in zip(counts.index, np.array(counts)):
            if day == clust2startday[clust]:
                new_fires_mat[year-min_year,day-days[0]] += count
            else:
                preex_fires_mat[year-min_year,day-days[0]] += count

# First, a simple plot by year
plt.figure(figsize=(10,7))
plt.plot(years, np.sum(new_fires_mat, axis=1), 'rs', label="New fires")
plt.plot(years, np.sum(preex_fires_mat, axis=1), 'bs', label="Preexisting fires")
ax = plt.gca()
ax.get_xaxis().get_major_formatter().set_useOffset(False)
plt.xlabel("Year")
plt.ylabel("Number of fires")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("pics/yearly_new_vs_preex.png")
plt.show()
plt.close()
plt.figure(figsize=(10,7))
plt.plot(days, np.sum(new_fires_mat, axis=0), 'r--', label="New fires")
plt.plot(days, np.sum(preex_fires_mat, axis=0), 'b--', label="Preexisting fires")
plt.xlabel("Day of season")
plt.ylabel("Number of fires (across all years)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("pics/daily_new_vs_preex.png")
plt.show()
plt.close()
plt.figure(figsize=(10,7))
plt.plot(days, new_fires_mat[2013-min_year,:], 'r--', label="New fires")
plt.plot(days, preex_fires_mat[2013-min_year,:], 'b--', label="Preexisting fires")
plt.xlabel("Day of season")
plt.ylabel("Number of fires (2013)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("pics/daily_new_vs_preex.png")
plt.show()
