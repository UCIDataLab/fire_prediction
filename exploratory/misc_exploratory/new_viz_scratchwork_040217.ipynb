J kg**-1 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 231:Convective inhibition:J kg**-1 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 232:Precipitable water:kg m**-2 (instant):regular_ll:unknown:level 0 200:fcst time 0 hrs:from 201307250000
# 233:Cloud water:kg m**-2 (instant):regular_ll:unknown:level 0 200:fcst time 0 hrs:from 201307250000
# 234:Relative humidity:% (instant):regular_ll:unknown:level 0 200:fcst time 0 hrs:from 201307250000
# 235:Total ozone:DU (instant):regular_ll:unknown:level 0 200:fcst time 0 hrs:from 201307250000
# 236:Total Cloud Cover:% (instant):regular_ll:unknown:level 0 244:fcst time 0 hrs:from 201307250000
# 237:Storm relative helicity:J kg**-1 (instant):regular_ll:heightAboveGroundLayer:levels 3000-0 m:fcst time 0 hrs:from 201307250000
# 238:U-component storm motion:m s**-1 (instant):regular_ll:heightAboveGroundLayer:levels 6000-0 m:fcst time 0 hrs:from 201307250000
# 239:V-component storm motion:m s**-1 (instant):regular_ll:heightAboveGroundLayer:levels 6000-0 m:fcst time 0 hrs:from 201307250000
# 240:Pressure:Pa (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 241:ICAO Standard Atmosphere reference height:m (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 242:Geopotential Height:gpm (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 243:Temperature:K (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 244:U component of wind:m s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 245:V component of wind:m s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 246:Vertical speed shear:s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201307250000
# 247:Pressure:Pa (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307250000
# 248:ICAO Standard Atmosphere reference height:m (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307250000
# 249:Geopotential Height:gpm (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307250000
# 250:U component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307250000
# 251:V component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307250000
# 252:Temperature:K (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307250000
# 253:Temperature:K (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307250000
# 254:Specific humidity:kg kg**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307250000
# 255:Pressure:Pa (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307250000
# 256:U component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307250000
# 257:V component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307250000
# 258:Temperature:K (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201307250000
# 259:U component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201307250000
# 260:V component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201307250000
# 261:Temperature:K (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201307250000
# 262:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201307250000
# 263:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201307250000
# 264:Temperature:K (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201307250000
# 265:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201307250000
# 266:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201307250000
# 267:Temperature:K (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201307250000
# 268:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201307250000
# 269:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201307250000
# 270:Geopotential Height:gpm (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201307250000
# 271:Relative humidity:% (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201307250000
# 272:Geopotential Height:gpm (instant):regular_ll:unknown:level 0 204:fcst time 0 hrs:from 201307250000
# 273:Relative humidity:% (instant):regular_ll:unknown:level 0 204:fcst time 0 hrs:from 201307250000
# 274:Temperature:K (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307250000
# 275:Relative humidity:% (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307250000
# 276:Specific humidity:kg kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307250000
# 277:U component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307250000
# 278:V component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307250000
# 279:Best (4-layer) lifted index:K (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 280:Convective available potential energy:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201307250000
# 281:Convective inhibition:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201307250000
# 282:Planetary boundary layer height:m (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 283:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.33-1.0 sigma value:fcst time 0 hrs:from 201307250000
# 284:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-1.0 sigma value:fcst time 0 hrs:from 201307250000
# 285:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.72-0.94 sigma value:fcst time 0 hrs:from 201307250000
# 286:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-0.72 sigma value:fcst time 0 hrs:from 201307250000
# 287:Temperature:K (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307250000
# 288:Potential temperature:K (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307250000
# 289:Relative humidity:% (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307250000
# 290:U component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307250000
# 291:V component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307250000
# 292:Vertical velocity:Pa s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307250000
# 293:Convective available potential energy:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 201307250000
# 294:Convective inhibition:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 201307250000
# 295:Pressure of level from which parcel was lifted:Pa (instant):regular_ll:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 201307250000
# 296:Wind speed (gust):m s**-1 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 297:Land-sea mask:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 298:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307250000
# 299:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 300:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 301:Temperature:K (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 302:Geopotential Height:gpm (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 303:Pressure:Pa (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 304:Vertical speed shear:s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 305:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 306:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 307:Temperature:K (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 308:Geopotential Height:gpm (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 309:Pressure:Pa (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 310:Vertical speed shear:s**-1 (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307250000
# 311:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201307250000
# 312:5-wave geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307250000
# 313:Geopotential height anomaly:gpm (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201307250000
# 314:Geopotential height anomaly:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307250000
# 315:5-wave geopotential height anomaly:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307250000

# %%
grbs0726 = pygrib.open("../20130726.grb")
for layer in grbs0726:
    print layer
# Looks like  there's a "wind speed" layer here at 4 that trips stuff up. however, it gets 
# corrected by the end, so maybe it's just this layer that's put elsewhere. Very odd.
# Out:
# 1:U component of wind:m s**-1 (instant):regular_ll:unknown:level 0 220:fcst time 0 hrs:from 201307260000
# 2:V component of wind:m s**-1 (instant):regular_ll:unknown:level 0 220:fcst time 0 hrs:from 201307260000
# 3:Ventilation Rate:m**2 s**-1 (instant):regular_ll:unknown:level 0 220:fcst time 0 hrs:from 201307260000
# 4:Wind speed (gust):m s**-1 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307260000
# 5:Geopotential Height:gpm (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 6:Temperature:K (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 7:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 8:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 9:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 10:Absolute vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 11:Ozone mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201307260000
# 12:Geopotential Height:gpm (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201307260000
# 13:Temperature:K (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201307260000
# 14:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201307260000
# 15:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201307260000
# 16:Absolute vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201307260000
# 17:Ozone mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201307260000
# 18:Geopotential Height:gpm (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 19:Temperature:K (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 20:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 21:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 22:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 23:Absolute vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 24:Ozone mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201307260000
# 25:Geopotential Height:gpm (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 26:Temperature:K (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 27:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 28:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 29:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 30:Absolute vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 31:Ozone mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201307260000
# 32:Geopotential Height:gpm (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 33:Temperature:K (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 34:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 35:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 36:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 37:Absolute vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 38:Ozone mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201307260000
# 39:Geopotential Height:gpm (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201307260000
# 40:Temperature:K (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201307260000
# 41:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201307260000
# 42:Vertical velocity:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201307260000
# 43:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201307260000
#
instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307260000
# 249:ICAO Standard Atmosphere reference height:m (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307260000
# 250:Geopotential Height:gpm (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307260000
# 251:U component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307260000
# 252:V component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307260000
# 253:Temperature:K (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201307260000
# 254:Temperature:K (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307260000
# 255:Specific humidity:kg kg**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307260000
# 256:Pressure:Pa (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307260000
# 257:U component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307260000
# 258:V component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201307260000
# 259:Temperature:K (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201307260000
# 260:U component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201307260000
# 261:V component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201307260000
# 262:Temperature:K (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201307260000
# 263:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201307260000
# 264:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201307260000
# 265:Temperature:K (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201307260000
# 266:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201307260000
# 267:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201307260000
# 268:Temperature:K (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201307260000
# 269:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201307260000
# 270:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201307260000
# 271:Geopotential Height:gpm (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201307260000
# 272:Relative humidity:% (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201307260000
# 273:Geopotential Height:gpm (instant):regular_ll:unknown:level 0 204:fcst time 0 hrs:from 201307260000
# 274:Relative humidity:% (instant):regular_ll:unknown:level 0 204:fcst time 0 hrs:from 201307260000
# 275:Temperature:K (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307260000
# 276:Relative humidity:% (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307260000
# 277:Specific humidity:kg kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307260000
# 278:U component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307260000
# 279:V component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201307260000
# 280:Best (4-layer) lifted index:K (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307260000
# 281:Convective available potential energy:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201307260000
# 282:Convective inhibition:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 0 hrs:from 201307260000
# 283:Planetary boundary layer height:m (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307260000
# 284:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.33-1.0 sigma value:fcst time 0 hrs:from 201307260000
# 285:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-1.0 sigma value:fcst time 0 hrs:from 201307260000
# 286:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.72-0.94 sigma value:fcst time 0 hrs:from 201307260000
# 287:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-0.72 sigma value:fcst time 0 hrs:from 201307260000
# 288:Temperature:K (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307260000
# 289:Potential temperature:K (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307260000
# 290:Relative humidity:% (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307260000
# 291:U component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307260000
# 292:V component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307260000
# 293:Vertical velocity:Pa s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201307260000
# 294:Convective available potential energy:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 201307260000
# 295:Convective inhibition:J kg**-1 (instant):regular_ll:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 201307260000
# 296:Pressure of level from which parcel was lifted:Pa (instant):regular_ll:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 0 hrs:from 201307260000
# 297:Land-sea mask:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307260000
# 298:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201307260000
# 299:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 300:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 301:Temperature:K (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 302:Geopotential Height:gpm (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 303:Pressure:Pa (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 304:Vertical speed shear:s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 305:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 306:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 307:Temperature:K (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 308:Geopotential Height:gpm (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 309:Pressure:Pa (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 310:Vertical speed shear:s**-1 (instant):regular_ll:potentialVorticity:level 2.147485648 K m2 kg-1 s-1:fcst time 0 hrs:from 201307260000
# 311:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201307260000
# 312:5-wave geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307260000
# 313:Geopotential height anomaly:gpm (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201307260000
# 314:Geopotential height anomaly:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307260000
# 315:5-wave geopotential height anomaly:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307260000

# %%
# OK, so how do we uniquely identify the layer of interest? We want layer name = Temperature,
# regular_ll (eg typeOfLevel) = surface, and level = 0. See if this is a unique layer everywhere
grbs0725 = pygrib.open("../20130725.grb")
            
for i,layer in enumerate(grbs0725):
    if layer.name == "Temperature" and layer.typeOfLevel == "surface":
        if layer.level == 0:
            print "layer %d has all 3" % (i+1)
        else:
            print "layer %d has 2" % (i+1)
print 'done'

grbs0726 = pygrib.open("../20130726.grb")
            
for i,layer in enumerate(grbs0726):
    if layer.name == "Temperature" and layer.typeOfLevel == "surface":
        if layer.level == 0:
            print "layer %d has all 3" % (i+1)
        else:
            print "layer %d has 2" % (i+1)
print 'done'
# Out:
# layer 211 has all 3
# done
# layer 212 has all 3
# done

# %%
grbs0725 = pygrib.open("20130725.grb")
for i,layer in enumerate(grbs0725):
    #if layer.name == "Relative humidity" and layer.level == 0:# and layer.typeOfLevel == "unknown":
    #if layer.name == 'Surface air relative humidity':
    if "loud" in layer.name:
        print layer
# ok wtf is the difference
#layer1 = grbs0725[234]
#layer2 = grbs0725[273]
#for key in layer1.keys():
#    try:
#        if layer1[key] != layer2[key]:
#            print "%s\t%s\t%s" %(key, str(layer1[key]), str(layer2[key]))
#    except Exception as e:
#        print "failed because " + str(e)
# Out:
# 45:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201307250000
# 54:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201307250000
# 62:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201307250000
# 70:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201307250000
# 78:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201307250000
# 86:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201307250000
# 94:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201307250000
# 102:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201307250000
# 110:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201307250000
# 118:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201307250000
# 126:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201307250000
# 134:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201307250000
# 142:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201307250000
# 150:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201307250000
# 158:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201307250000
# 166:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201307250000
# 174:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201307250000
# 182:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201307250000
# 190:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201307250000
# 199:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201307250000
# 206:Cloud mixing ratio:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201307250000
# 233:Cloud water:kg m**-2 (instant):regular_ll:unknown:level 0 200:fcst time 0 hrs:from 201307250000
# 236:Total Cloud Cover:% (instant):regular_ll:unknown:level 0 244:fcst time 0 hrs:from 201307250000

# %%
grbs0725 = pygrib.open("../20130725.grb")
            
for i,layer in enumerate(grbs0725):
    if layer.name == "Relative humidity" and layer.level == 0 \
        and layer.typeOfLevel == "unknown" and layer.typeOfFirstFixedSurface == '200':
        print "layer %d" % (i+1)
        print "toffs: " + str(layer.typeOfFirstFixedSurface == '200')

grbs0726 = pygrib.open("../20130726.grb")
            
for i,layer in enumerate(grbs0726):
    if layer.name == "Relative humidity" and layer.level == 0 \
        and layer.typeOfLevel == "unknown" and layer.typeOfFirstFixedSurface == '200':
        print "layer %d" % (i+1)
        print "toffs: " + str(layer.typeOfFirstFixedSurface)
# Out:
# layer 234
# toffs: True
# layer 235
# toffs: 200

# %%
vals = layer1.values
lats,lons = layer1.latlons()
print "val shape: %s\tlat shape: %s\tlon shape: %s" %(str(vals.shape), str(lats.shape), str(lons.shape))
print lons[0,:]
# Out:
# val shape: (361, 720)	lat shape: (361, 720)	lon shape: (361, 720)
# [   0.     0.5    1.     1.5    2.     2.5    3.     3.5    4.     4.5
#     5.     5.5    6.     6.5    7.     7.5    8.     8.5    9.     9.5
#    10.    10.5   11.    11.5   12.    12.5   13.    13.5   14.    14.5
#    15.    15.5   16.    16.5   17.    17.5   18.    18.5   19.    19.5
#    20.    20.5   21.    21.5   22.    22.5   23.    23.5   24.    24.5
#    25.    25.5   26.    26.5   27.    27.5   28.    28.5   29.    29.5
#    30.    30.5   31.    31.5   32.    32.5   33.    33.5   34.    34.5
#    35.    35.5   36.    36.5   37.    37.5   38.    38.5   39.    39.5
#    40.    40.5   41.    41.5   42.    42.5   43.    43.5   44.    44.5
#    45.    45.5   46.    46.5   47.    47.5   48.    48.5   49.    49.5
#    50.    50.5   51.    51.5   52.    52.5   53.    53.5   54.    54.5
#    55.    55.5   56.    56.5   57.    57.5   58.    58.5   59.    59.5
#    60.    60.5   61.    61.5   62.    62.5   63.    63.5   64.    64.5
#    65.    65.5   66.    66.5   67.    67.5   68.    68.5   69.    69.5
#    70.    70.5   71.    71.5   72.    72.5   73.    73.5   74.    74.5
#    75.    75.5   76.    76.5   77.    77.5   78.    78.5   79.    79.5
#   295.   295.5  296.   296.5  297.   297.5  298.   298.5  299.   299.5
#   300.   300.5  301.   301.5  302.   302.5  303.   303.5  304.   304.5
#   305.   305.5  306.   306.5  307.   307.5  308.   308.5  309.   309.5
#   310.   310.5  311.   311.5  312.   312.5  313.   313.5  314.   314.5
#   315.   315.5  316.   316.5  317.   317.5  318.   318.5  319.   319.5
#   320.   320.5  321.   321.5  322.   322.5  323.   323.5  324.   324.5
#   325.   325.5  326.   326.5  327.   327.5  328.   328.5  329.   329.5
#   330.   330.5  331.   331.5  332.   332.5  333.   333.5  334.   334.5
#   335.   335.5  336.   336.5  337.   337.5  338.   338.5  339.   339.5
#   340.   340.5  341.   341.5  342.   342.5  343.   343.5  344.   344.5
#   345.   345.5  346.   346.5  347.   347.5  348.   348.5  349.   349.5
#   350.   350.5  351.   351.5  352.   352.5  353.   353.5  354.   354.5
#   355.   355.5  356.   356.5  357.   357.5  358.   358.5  359.   359.5]

# %%
temp_vals = grbs0725.select(name='Temperature', typeOfLevel='surface')[0].values
ak_bb = [55,71,-165,-138]
plot_bb_0 = np.where(lats[:,0] <= ak_bb[0])[0][0]
plot_bb_1 = np.where(lats[:,0] <= ak_bb[1])[0][0]
plot_bb_2 = np.where(lons[0,:] >= (ak_bb[2] % 360))[0][0]
plot_bb_3 = np.where(lons[0,:] >= (ak_bb[3] % 360))[0][0]
plot_bb = [plot_bb_0, plot_bb_1, plot_bb_2, plot_bb_3]
print "plot_bb: " + str(plot_bb)
mp = Basemap(projection="merc",
              lat_0=55, lon_0=-165,
              llcrnrlat=55,
              llcrnrlon=-165,
              urcrnrlat=71,
              urcrnrlon=-138,
              resolution='i')
mp.drawcoastlines()
mp.imshow(temp_vals[plot_bb_0-1:plot_bb_1-1:-1, plot_bb_2:plot_bb_3])
mp.colorbar()
# Out:
# plot_bb: [70, 38, 390, 444]

# %%
plt.imshow(temp_vals[38:70,390:444])

# %%
# Let's try our new function
import os
os.chdir('/Users/zbutler/research/fire_prediction')
import plotting.plot_map as pm
import cPickle
with open('data/temp_2013.pkl') as fpkl:
    temp_dict = cPickle.load(fpkl)
pm.draw_map_nogrid_static(ak_bb, month=1, day=9, gfs_dict=temp_dict)

# %%
# try to make an animated thingy
def day2monthday(my_day, leapyear=False):
    if leapyear:
        month_arr = [31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    else:
        month_arr = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    month = 1
    days_left = my_day
    while days_left >= month_arr[month-1]:
        days_left -= month_arr[month-1]
        month += 1
    day = days_left + 1
    return month,day
    
def monthday2day(month, day, leapyear=False):
    """Convert month/day into days since Jan 1"""
    if leapyear:
        month_arr = [31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    else:
        month_arr = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    days = 0
    for mon in xrange(1, month):
        days += month_arr[mon - 1]
    days += day - 1
    return days

def update(i):
    monthday = day2monthday(i)
    temp_vals = temp_dict[monthday]
    im.set_data(temp_vals[plot_bb_0-1:plot_bb_1-1:-1, plot_bb_2:plot_bb_3])
    plt.title("Temps for %d/%d" %monthday)
    print "butts " + str(i)
    return im,
             
fig,ax = plt.subplots()
mp = Basemap(projection="merc",
              lat_0=55, lon_0=-165,
              llcrnrlat=55,
              llcrnrlon=-165,
              urcrnrlat=71,
              urcrnrlon=-138,
              resolution='i')
im = mp.imshow(temp_vals[plot_bb_0-1:plot_bb_1-1:-1, plot_bb_2:plot_bb_3], animated=True)
mp.drawcoastlines()
mp.colorbar()

anim = FuncAnimation(fig, update, frames=range(10,20), interval=200, blit=True)
# Out:
# butts 10

# %%
# animation round 2: save a bunch of pics and use mac's "convert" to turn them into a gif
mp = Basemap(projection="merc",
              lat_0=55, lon_0=-165,
              llcrnrlat=55,
              llcrnrlon=-165,
              urcrnrlat=71,
              urcrnrlon=-138,
              resolution='i')
start_day = monthday2day(6,1)
end_day = monthday2day(9,1)
min_temp = temp_dict['min']
max_temp = temp_dict['max']
for dayy in xrange(start_day, end_day):
    monthday = day2monthday(dayy)
    temp_vals = temp_dict[monthday]
    mp.imshow(temp_vals[plot_bb_0-1:plot_bb_1-1:-1, plot_bb_2:plot_bb_3],
              vmin=min_temp, vmax=max_temp)
    plt.title("Temps for %d/%d" %monthday)
    mp.drawcoastlines()
    mp.colorbar()
    plt.savefig('gifmaking/day%d.png' % dayy)
    plt.close()

os.system('convert -delay 100 -loop 0 gifmaking/day*.png gifmaking/temp_loop_2013.gif')
print "done"
# Out:
# done

# %%
# Now let's do humidity
with open('data/hum_2013.pkl') as fpkl:
    hum_dict = cPickle.load(fpkl)
mp = Basemap(projection="merc",
              lat_0=55, lon_0=-165,
              llcrnrlat=55,
              llcrnrlon=-165,
              urcrnrlat=71,
              urcrnrlon=-138,
              resolution='i')
start_day = monthday2day(6,1)
end_day = monthday2day(9,1)
min_hum = hum_dict['min']
max_hum = hum_dict['max']
for dayy in xrange(start_day, end_day):
    monthday = day2monthday(dayy)
    hum_vals = hum_dict[monthday]
    mp.imshow(hum_vals[plot_bb_0-1:plot_bb_1-1:-1, plot_bb_2:plot_bb_3],
              vmin=min_hum, vmax=max_hum)
    plt.title("Humidity for %d/%d" %monthday)
    mp.drawcoastlines()
    mp.colorbar()
    plt.savefig('gifmaking/day%d.png' % dayy)
    plt.close()

os.system('convert -delay 100 -loop 0 gifmaking/day*.png gifmaking/humidity_loop_2013.gif')
print "done"
# Out:
# done

# %%
# let's try drawing gridlines
meridians = np.arange(ak_bb[2], ak_bb[3], 1)  # 111km in a degree
parallels = np.arange(ak_bb[0], ak_bb[1], 1)  # 111km in a degree
mp = Basemap(projection="merc",
              lat_0=55, lon_0=-165,
              llcrnrlat=55,
              llcrnrlon=-165,
              urcrnrlat=71,
              urcrnrlon=-138,
              resolution='i')
temp_vals = temp_dict[(6,9)]
mp.imshow(temp_vals[plot_bb_0-1:plot_bb_1-1:-1, plot_bb_2:plot_bb_3],
              vmin=min_temp, vmax=max_temp)
mp.drawparallels(parallels)
mp.drawmeridians(meridians)
mp.drawcoastlines()
mp.colorbar()
plt.title("Temperature for 6/09")
plt.show()

# %%
with open("data/modis.pkl") as fpd:
    modis = cPickle.load(fpd)

# %%
# individual fire plot with grid
from IPython import display
fire_bb = [64.6, 64.9, -147, -146.4]
meridians = np.arange(fire_bb[2], fire_bb[3], 1.1/111)  # 111km in a degree
parallels = np.arange(fire_bb[0], fire_bb[1], 1.1/111)  # 111km in a degree
mp = Basemap(projection="merc",
              lat_0=float(fire_bb[0]+fire_bb[1])/2, lon_0=float(fire_bb[2]+fire_bb[3])/2,
              llcrnrlat=fire_bb[0],
              llcrnrlon=fire_bb[2],
              urcrnrlat=fire_bb[1],
              urcrnrlon=fire_bb[3],
              resolution='i')
my_fires = modis[(modis.lat < fire_bb[1]) & (modis.lat > fire_bb[0]) &
                 (modis.long < fire_bb[3]) & (modis.long > fire_bb[2])]
month = 6
day = 25
prev_lats = []
prev_longs = []
while month < 8 or day < 12:
    todays_fires = my_fires[(my_fires.year == 2013) & (my_fires.month == month) &
                            (my_fires.day == day)]
    display.clear_output(wait=True)
    plt.figure(figsize=(5,10))
    mp.drawcoastlines()
    if len(prev_lats):
        mp.plot(prev_longs, prev_lats, 'ko')
    if len(todays_fires):
        today_longs, today_lats = mp(np.array(todays_fires.long), np.array(todays_fires.lat))
        mp.plot(today_longs, today_lats, 'ro')
        prev_lats += list(today_lats)
        prev_longs += list(today_longs)
    mp.drawparallels(parallels)
    mp.drawmeridians(meridians)
    plt.title("Fires in 5km BB on %d %d" %(month, day))
    plt.show()
    raw_input("hit enter")
    day += 1
    if day >= 31 or (day >= 30 and month == 6):
        day = 1
        month += 1
# Out:
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-172-2a667dfbdb8d> in <module>()
#      34     plt.title("Fires in 5km BB on %d %d" %(month, day))
#      35     plt.show()
# ---> 36     raw_input("hit enter")
#      37     day += 1
#      38     if day >= 31 or (day >= 30 and month == 6):
#
# /Users/zbutler/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     687             self._parent_ident,
#     688             self._parent_header,
# --> 689             password=False,
#     690         )
#     691
#
# /Users/zbutler/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     717             except KeyboardInterrupt:
#     718                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 719                 raise KeyboardInterrupt
#     720             else:
#     721                 break
#
# KeyboardInterrupt:

# %%
import matplotlib.patches as patches
# individual fire plot with grid and cells
fire_bb = [64.6, 64.9, -147, -146.4]
meridians = np.arange(fire_bb[2], fire_bb[3], 1.1/111)  # 111km in a degree
parallels = np.arange(fire_bb[0], fire_bb[1], 1.1/111)  # 111km in a degree
my_fires = modis[(modis.lat < fire_bb[1]) & (modis.lat > fire_bb[0]) &
                 (modis.long < fire_bb[3]) & (modis.long > fire_bb[2])]

# %%
mp = Basemap(projection="merc",
              lat_0=float(fire_bb[0]+fire_bb[1])/2, lon_0=float(fire_bb[2]+fire_bb[3])/2,
              llcrnrlat=fire_bb[0],
              llcrnrlon=fire_bb[2],
              urcrnrlat=fire_bb[1],
              urcrnrlon=fire_bb[3])
month = 6
day = 25
prev_lat_cells = []
prev_long_cells = []
while month < 8 or day < 12:
    todays_fires = my_fires[(my_fires.year == 2013) & (my_fires.month == month) &
                            (my_fires.day == day)]
    display.clear_output(wait=True)
    plt.figure(figsize=(5,10))
    mp.drawcoastlines()
#    if len(prev_lat_cells):
#        mp.plot(prev_long_cells, prev_lat_cells, 'ko')
    if len(todays_fires):
        today_longs, today_lats = np.array(todays_fires.long), np.array(todays_fires.lat)
        print 'yolo'
        for lon,lat in zip(today_longs, today_lats):
            lon_cell = np.where(meridians > lon)[0][0]
            lat_cell = np.where(parallels > lat)[0][0]
            plotlat, plotlon = mp(lon, lat)
            mp.plot(plotlon, plotlat, 'r+')
            print "plotlat, plotlon " + str((plotlat, plotlon))
            rect = patches.Rectangle(mp(meridians[lon_cell-1], parallels[lat_cell-1]), 1.1/111, 1.1/111, facecolor='red')
            print rect
            print mp(meridians[-10:], parallels[-10:])
            plt.gca().add_patch(rect)
            prev_lat_cells.append(lat_cell)
            prev_long_cells.append(lon_cell)
            break
        print 'yolo 2'
    mp.drawparallels(parallels)
    mp.drawmeridians(meridians)
    plt.title("Fires in 5km BB on %d %d" %(month, day))
    plt.show()
    raw_input("hit enter")
    day += 1
    if day >= 31 or (day >= 30 and month == 6):
        day = 1
        month += 1
# Out:
# yolo
# plotlat, plotlon (44366.754839587891, 23629.90969092399)
# Rectangle(44077.2,23158.9;0.00990991x0.00990991)
# (array([ 56198.49051684,  57300.42170345,  58402.35289005,  59504.28407665,
#         60606.21526326,  61708.14644986,  62810.07763647,  63912.00882307,
#         65013.94000968,  66115.87119628]), array([ 54156.35922709,  56745.64763833,  59335.88872078,  61927.08325326,
#         64519.23201553,  67112.33578824,  69706.39535299,  72301.41149229,
#         74897.38498958,  77494.31662921]))
# yolo 2
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-192-1bd3afdf95a2> in <module>()
#      38     plt.title("Fires in 5km BB on %d %d" %(month, day))
#      39     plt.show()
# ---> 40     raw_input("hit enter")
#      41     day += 1
#      42     if day >= 31 or (day >= 30 and month == 6):
#
# /Users/zbutler/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     687             self._parent_ident,
#     688             self._parent_header,
# --> 689             password=False,
#     690         )
#     691
#
# /Users/zbutler/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     717             except KeyboardInterrupt:
#     718                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 719                 raise KeyboardInterrupt
#     720             else:
#     721                 break
#
# KeyboardInterrupt:

# %%
# time dependent plot
with open("modis.pkl") as fpkl:
    modis = cPickle.load(fpkl)
    
fire_bb = [64.6, 64.9, -147, -146.4]
meridians = np.arange(fire_bb[2], fire_bb[3], 1.1/111)  # 111km in a degree
parallels = np.arange(fire_bb[0], fire_bb[1], 1.1/111)  # 111km in a degree
mp = Basemap(projection="merc",
              lat_0=float(fire_bb[0]+fire_bb[1])/2, lon_0=float(fire_bb[2]+fire_bb[3])/2,
              llcrnrlat=fire_bb[0],
              llcrnrlon=fire_bb[2],
              urcrnrlat=fire_bb[1],
              urcrnrlon=fire_bb[3],
              resolution='i')
my_fires = modis[(modis.lat < fire_bb[1]) & (modis.lat > fire_bb[0]) &
                 (modis.long < fire_bb[3]) & (modis.long > fire_bb[2])]
month = 6
day = 25
prev_lats = []
prev_longs = []
while month < 8 or day < 12:
    todays_fires = my_fires[(my_fires.year == 2013) & (my_fires.month == month) &
                            (my_fires.day == day)]
    display.clear_output(wait=True)
    plt.figure(figsize=(5,10))
    mp.drawcoastlines()
    if len(prev_lats):
        mp.plot(prev_longs, prev_lats, 'ko')
    if len(todays_fires):
        today_longs, today_lats = mp(np.array(todays_fires.long), np.array(todays_fires.lat))
        today_times = np.array(today_fires.hour)
        mp.plot(today_longs, today_lats, c=today_times)
        prev_lats += list(today_lats)
        prev_longs += list(today_longs)
    mp.drawparallels(parallels)
    mp.drawmeridians(meridians)
    plt.title("Fires in 5km BB on %d %d" %(month, day))
    plt.show()
    raw_input("hit enter")
    day += 1
    if day >= 31 or (day >= 30 and month == 6):
        day = 1
        month += 1
